# %%
import json

record= {
        '1001': {'name': 'Parle G Original', 'pr': 10, 'qn': 500, "expiry":"feb 2023",  'wa': 'NA'},
        '1002': {'name': 'Bingo! Mad Angle', 'pr': 10, 'qn': 200, "expiry":"dec 2023", 'wa': 'yes'},
        '1003': {'name': 'Colgate Maxfresh', 'pr': 80, 'qn': 1000, "expiry":"oct 2023", 'wa': 'yes'},
        '1004': {'name': 'Kelloggs pringles', 'pr': 50, 'qn': 1000, "expiry":"oct 2023", 'wa': 'NA'},
        '1005': {'name': 'Himalaya Baby Powder','pr': 240, 'qn': 100, "expiry":"mar 2023", 'wa': 'yes'},
        '1006': {'name': 'Himalaya Face wash', 'pr': 300, 'qn': 200, "expiry":"nov 2023", 'wa': 'yes'},
        '1007': {'name': 'Dairy Milk Silk', 'pr': 40, 'qn': 150, "expiry":"june 2023", 'wa': 'yes'},
        '1008': {'name': 'Saffola Active', 'pr': 260, 'qn': 200, "expiry":"july 2023", 'wa': 'NA'},
        '1009': {'name': 'Dabur Amla Hair Oil', 'pr': 300, 'qn': 800, "expiry":"may 2023", 'wa': 'NA'},
        '1010': {'name': 'Cadbury Oreo', 'pr': 60, 'qn': 500, "expiry":"feb 2023", 'wa': 'yes'},    
        '2001': {'name': 'Washing Machine',  'pr': 15000, 'qn': 30,  "expiry":"jan 2023", 'wa': 'Yes' },
        '2002': {'name': 'Microwave Oven',  'pr': 5500, 'qn': 100, "expiry":"nov 2023", 'wa': 'Yes'},
        '2003': {'name': 'Mixer Grinder', 'pr': 1500, 'qn': 100, "expiry":"jan 2023", 'wa': 'Yes'},
        '2004': {'name': 'Induction Oven', 'pr': 3500, 'qn': 100, "expiry":"aug 2023", 'wa': 'Yes'},
        '2005': {'name': 'Air Fryer', 'pr': 9000, 'qn': 100, "expiry":"dec 2023", 'wa': 'Yes'},
        '2006': {'name': 'Blender', 'pr': 700, 'qn': 200, "expiry":"sept 2023", 'wa': 'Yes'},
        '2007': {'name': 'Vaccum Cleaner', 'pr': 8000, 'qn': 50, "expiry":"oct 2023", 'wa': 'Yes'},
        '2008': {'name': 'Toaster', 'pr': 800, 'qn': 150, "expiry":"oct 2023", 'wa': 'Yes'},
        '2009': {'name': 'Grill', 'pr': 500, 'qn': 120, "expiry":"sept 2023", 'wa': 'Yes'},
        '2010': {'name': 'Sandwich Maker', 'pr': 750, 'qn': 80, "expiry":"apr 2023", 'wa': 'Yes'},  
        '3001': {'name': 'Chocolate Cake', 'pr': 80, 'qn': 50, "expiry":"apr 2023", 'wa': 'NA'},
        '3002': {'name': 'Vanilla Ice-cream', 'pr': 100, 'qn': 100, "expiry":"sept 2023", 'wa': 'NA'},
        '3003': {'name': 'Coca-cola', 'pr': 95, 'qn': 100, "expiry":"apr 2023", 'wa': 'NA'},
        '3004': {'name': 'Jolly Rancher', 'pr': 10, 'qn': 1000, "expiry":"20 oct 2023", 'wa': 'NA'},
        '3005': {'name': 'Pasta', 'pr': 60, 'qn': 100, "expiry":"oct 2023", 'wa': 'NA'},
        '3006': {'name': 'Chewing Gum', 'pr': 5, 'qn': 900, "expiry":"apr 2023", 'wa': 'NA'},
        '3007': {'name': 'Cotton Candy', 'pr': 50, 'qn': 60, "expiry":"apr 2023", 'wa': 'NA'},
        '3008': {'name': 'Oreo', 'pr': 90, 'qn': 200, "expiry":"sept 2023", 'wa': 'NA'},
        '3009': {'name': 'Cookies', 'pr': 50, 'qn': 150, "expiry":"apr 2023", 'wa': 'NA'},
        '3010': {'name': 'Cheetos', 'pr': 30, 'qn': 300, "expiry":"sept 2023", 'wa': 'NA'}}

fd = open("record.json",'w')
js = json.dump(record, fd)
fd.close()

# %% [markdown]
# ### Read Data from JSON

# %%
fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'1001': {'expiry': 'feb 2023',
#   'name': 'Parle G Original',
#   'pr': 10,
#   'qn': 500,
#   'wa': 'NA'},
#  '1002': {'expiry': 'dec 2023',
#   'name': 'Bingo! Mad Angle',
#   'pr': 10,
#   'qn': 200,
#   'wa': 'yes'},
#  '1003': {'expiry': 'oct 2023',
#   'name': 'Colgate Maxfresh',
#   'pr': 80,
#   'qn': 1000,
#   'wa': 'yes'},
#  '1004': {'expiry': 'oct 2023',
#   'name': 'Kelloggs pringles',
#   'pr': 50,
#   'qn': 1000,
#   'wa': 'NA'},
#  '1005': {'expiry': 'mar 2023',
#   'name': 'Himalaya Baby Powder',
#   'pr': 240,
#   'qn': 100,
#   'wa': 'yes'},
#  '1006': {'expiry': 'nov 2023',
#   'name': 'Himalaya Face wash',
#   'pr': 300,
#   'qn': 200,
#   'wa': 'yes'},
#  '1007': {'expiry': 'june 2023',
#   'name': 'Dairy Milk Silk',
#   'pr': 40,
#   'qn': 150,
#   'wa': 'yes'},
#  '1008': {'expiry': 'july 2023',
#   'name': 'Saffola Active',
#   'pr': 260,
#   'qn': 200,
#   'wa': 'NA'},
#  '1009': {'expiry': 'may 2023',
#   'name': 'Dabur Amla Hair Oil',
#   'pr': 300,
# ...

# %% [markdown]
# ### Add New Item to Inventory

# %%
prod_id = input("Enter the Product ID: ")
name = input("Enter the Name of the Product: ")
pr = int(input("Enter the price per Item: "))
qn = int(input("Enter The Quantity of the Product you want to add: "))
expiry = input("Enter the expiry date of the Product: ")
wa = input("Enter the warenty application of the product: ")

record[prod_id] = {"name":name,"pr":pr,"qn":qn,"expiry":expiry,"wa": wa}

js = json.dumps(record)

fd = open("record.json","w")
fd.write(js)
fd.close()
# Out:
# Enter the Product ID: 3030
# Enter the Name of the Product: Pepsi
# Enter the price per Item: 50
# Enter The Quantity of the Product you want to add: 100
# Enter the expiry date of the Product: jan 2022
# Enter the warenty application of the product: NA

# %%
record
# Out:
# {'1001': {'expiry': 'feb 2023',
#   'name': 'Parle G Original',
#   'pr': 10,
#   'qn': 500,
#   'wa': 'NA'},
#  '1002': {'expiry': 'dec 2023',
#   'name': 'Bingo! Mad Angle',
#   'pr': 10,
#   'qn': 200,
#   'wa': 'yes'},
#  '1003': {'expiry': 'oct 2023',
#   'name': 'Colgate Maxfresh',
#   'pr': 80,
#   'qn': 1000,
#   'wa': 'yes'},
#  '1004': {'expiry': 'oct 2023',
#   'name': 'Kelloggs pringles',
#   'pr': 50,
#   'qn': 1000,
#   'wa': 'NA'},
#  '1005': {'expiry': 'mar 2023',
#   'name': 'Himalaya Baby Powder',
#   'pr': 240,
#   'qn': 100,
#   'wa': 'yes'},
#  '1006': {'expiry': 'nov 2023',
#   'name': 'Himalaya Face wash',
#   'pr': 300,
#   'qn': 200,
#   'wa': 'yes'},
#  '1007': {'expiry': 'june 2023',
#   'name': 'Dairy Milk Silk',
#   'pr': 40,
#   'qn': 150,
#   'wa': 'yes'},
#  '1008': {'expiry': 'july 2023',
#   'name': 'Saffola Active',
#   'pr': 260,
#   'qn': 200,
#   'wa': 'NA'},
#  '1009': {'expiry': 'may 2023',
#   'name': 'Dabur Amla Hair Oil',
#   'pr': 300,
# ...
